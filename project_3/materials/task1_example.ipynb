# %% [markdown]
# # Пример оформления Задания 1
#
# Это шаблон — он показывает только **ФОРМАТ** оформления ноутбука.
# Конкретные задания и условия — в `readme.md`.
# **Не копируй — пиши свой код самостоятельно!**

# %% [markdown]
# ## Имя Фамилия — Проект 3
#
# Краткое описание: в этом проекте я анализирую данные клиники «Здоровье+» с помощью Python и pandas.
# В первом задании я осваиваю базовые конструкции Python в Jupyter Notebook.

# %%
# Пример: создание переменной и её вывод
example_name = "Название клиники"  # замени на нужное значение
example_count = 4                   # количество филиалов
print(f"Клиника: {example_name}, филиалов: {example_count}")

# %%
# Пример: список и цикл for
example_list = ["Элемент 1", "Элемент 2", "Элемент 3"]

for item in example_list:
    print(f"Элемент: {item}")

# %%
# Пример: функция с аргументом и возвращаемым значением
def example_function(value):
    """Краткое описание: что делает эта функция."""
    return value * 2  # замени логику на нужную по заданию

result = example_function(5)
print(result)

# %% [markdown]
# ## Выводы
#
# После каждого блока кода добавляй Markdown-ячейку с кратким пояснением:
# что ты сделал, что получил и что это означает в контексте задачи.
# Это улучшает читаемость ноутбука и помогает при проверке.
